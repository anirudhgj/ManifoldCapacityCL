# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import os
import glob
import sys
import numpy as np
from natsort import natsorted

sys.path.append("../")
sys.path.append("../CL")
import mftma
from utils import factory
from utils.toolkit import count_parameters
from torch.utils.data import DataLoader
from utils.data_manager import DataManager

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
task_id = 8

# %%
config = {
    "prefix": "reproduce",
    "dataset": "cifar100",
    "memory_size": 2000,
    "memory_per_class": 20,
    "fixed_memory": "False",
    "shuffle": "True",
    "init_cls": 10,
    "increment": 10,
    "model_name": "ewc",
    "convnet_type": "resnet32",
    "device": [torch.device("cuda:0")],
    "seed": [1993],
}
model = factory.get_model("ewc", config)
model._network.update_fc((task_id + 1) * 10)
model._network.to(device)
# Out:
# IncrementalNet(
#   (convnet): CifarResNet(
#     (conv_1_3x3): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn_1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (stage_1): Sequential(
#       (0): ResNetBasicblock(
#         (conv_a): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): ResNetBasicblock(
#         (conv_a): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ResNetBasicblock(
#         (conv_a): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): ResNetBasicblock(
#         (conv_a): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): ResNetBasicblock(
#         (conv_a): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (stage_2): Sequential(
#       (0): ResNetBasicblock(
#         (conv_a): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): DownsampleA(
#           (avg): AvgPool2d(kernel_size=1, stride=2, padding=0)
#         )
#       )
#       (1): ResNetBasicblock(
#         (conv_a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ResNetBasicblock(
#         (conv_a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): ResNetBasicblock(
#         (conv_a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): ResNetBasicblock(
#         (conv_a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (stage_3): Sequential(
#       (0): ResNetBasicblock(
#         (conv_a): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): DownsampleA(
#           (avg): AvgPool2d(kernel_size=1, stride=2, padding=0)
#         )
#       )
#       (1): ResNetBasicblock(
#         (conv_a): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): ResNetBasicblock(
#         (conv_a): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): ResNetBasicblock(
#         (conv_a): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): ResNetBasicblock(
#         (conv_a): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_a): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv_b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn_b): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (fc): Linear(in_features=64, out_features=10, bias=True)
#   )
#   (fc): SimpleLinear()
# )

# %%
weights = natsorted(glob.glob("../CL/weights/*"))
task1_weights = torch.load(weights[task_id])["model_state_dict"]

# %%
current_model = list(model._network.state_dict().keys())
saved_model = list(task1_weights.keys())

# %%
new_state_dict = {
    key: value for key, value in task1_weights.items() if key in current_model
}

# %%
model._network.load_state_dict(new_state_dict)
# Out:
# <All keys matched successfully>

# %%
data_manager = DataManager(
    config["dataset"],
    config["shuffle"],
    config["seed"],
    config["init_cls"],
    config["increment"],
)

batch_size = 128
num_workers = 4

train_dataset = data_manager.get_dataset(
    np.arange(0, 10),
    source="train",
    mode="train",
)
train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers
)
test_dataset = data_manager.get_dataset(
    np.arange(0, (task_id + 1) * 10), source="test", mode="test"
)
test_loader = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
model.test_loader = test_loader
model.eval_task()
# Out:
# ({'grouped': {'total': 0.72,
#    '00-09': 0.0,
#    '10-19': 1.1,
#    '20-29': 0.2,
#    '30-39': 0.1,
#    '40-49': 0.1,
#    '50-59': 1.2,
#    '60-69': 1.2,
#    '70-79': 1.0,
#    '80-89': 1.6,
#    'old': 0,
#    'new': 0.72},
#   'top1': 0.72,
#   'top5': 4.7},
#  None)

# %%
saved_model
# Out:
# ['convnet.conv_1_3x3.weight',
#  'convnet.bn_1.weight',
#  'convnet.bn_1.bias',
#  'convnet.bn_1.running_mean',
#  'convnet.bn_1.running_var',
#  'convnet.bn_1.num_batches_tracked',
#  'convnet.stage_1.0.conv_a.weight',
#  'convnet.stage_1.0.bn_a.weight',
#  'convnet.stage_1.0.bn_a.bias',
#  'convnet.stage_1.0.bn_a.running_mean',
#  'convnet.stage_1.0.bn_a.running_var',
#  'convnet.stage_1.0.bn_a.num_batches_tracked',
#  'convnet.stage_1.0.conv_b.weight',
#  'convnet.stage_1.0.bn_b.weight',
#  'convnet.stage_1.0.bn_b.bias',
#  'convnet.stage_1.0.bn_b.running_mean',
#  'convnet.stage_1.0.bn_b.running_var',
#  'convnet.stage_1.0.bn_b.num_batches_tracked',
#  'convnet.stage_1.1.conv_a.weight',
#  'convnet.stage_1.1.bn_a.weight',
#  'convnet.stage_1.1.bn_a.bias',
#  'convnet.stage_1.1.bn_a.running_mean',
#  'convnet.stage_1.1.bn_a.running_var',
#  'convnet.stage_1.1.bn_a.num_batches_tracked',
#  'convnet.stage_1.1.conv_b.weight',
#  'convnet.stage_1.1.bn_b.weight',
#  'convnet.stage_1.1.bn_b.bias',
#  'convnet.stage_1.1.bn_b.running_mean',
#  'convnet.stage_1.1.bn_b.running_var',
#  'convnet.stage_1.1.bn_b.num_batches_tracked',
#  'convnet.stage_1.2.conv_a.weight',
#  'convnet.stage_1.2.bn_a.weight',
#  'convnet.stage_1.2.bn_a.bias',
#  'convnet.stage_1.2.bn_a.running_mean',
#  'convnet.stage_1.2.bn_a.running_var',
#  'convnet.stage_1.2.bn_a.num_batches_tracked',
#  'convnet.stage_1.2.conv_b.weight',
#  'convnet.stage_1.2.bn_b.weight',
#  'convnet.stage_1.2.bn_b.bias',
#  'convnet.stage_1.2.bn_b.running_mean',
#  'convnet.stage_1.2.bn_b.running_var',
#  'convnet.stage_1.2.bn_b.num_batches_tracked',
#  'convnet.stage_1.3.conv_a.weight',
#  'convnet.stage_1.3.bn_a.weight',
#  'convnet.stage_1.3.bn_a.bias',
#  'convnet.stage_1.3.bn_a.running_mean',
#  'convnet.stage_1.3.bn_a.running_var',
#  'convnet.stage_1.3.bn_a.num_batches_tracked',
#  'convnet.stage_1.3.conv_b.weight',
#  'convnet.stage_1.3.bn_b.weight',
#  'convnet.stage_1.3.bn_b.bias',
#  'convnet.stage_1.3.bn_b.running_mean',
#  'convnet.stage_1.3.bn_b.running_var',
#  'convnet.stage_1.3.bn_b.num_batches_tracked',
#  'convnet.stage_1.4.conv_a.weight',
#  'convnet.stage_1.4.bn_a.weight',
#  'convnet.stage_1.4.bn_a.bias',
#  'convnet.stage_1.4.bn_a.running_mean',
#  'convnet.stage_1.4.bn_a.running_var',
#  'convnet.stage_1.4.bn_a.num_batches_tracked',
#  'convnet.stage_1.4.conv_b.weight',
#  'convnet.stage_1.4.bn_b.weight',
#  'convnet.stage_1.4.bn_b.bias',
#  'convnet.stage_1.4.bn_b.running_mean',
#  'convnet.stage_1.4.bn_b.running_var',
#  'convnet.stage_1.4.bn_b.num_batches_tracked',
#  'convnet.stage_2.0.conv_a.weight',
#  'convnet.stage_2.0.bn_a.weight',
#  'convnet.stage_2.0.bn_a.bias',
#  'convnet.stage_2.0.bn_a.running_mean',
#  'convnet.stage_2.0.bn_a.running_var',
#  'convnet.stage_2.0.bn_a.num_batches_tracked',
#  'convnet.stage_2.0.conv_b.weight',
#  'convnet.stage_2.0.bn_b.weight',
#  'convnet.stage_2.0.bn_b.bias',
#  'convnet.stage_2.0.bn_b.running_mean',
#  'convnet.stage_2.0.bn_b.running_var',
#  'convnet.stage_2.0.bn_b.num_batches_tracked',
#  'convnet.stage_2.1.conv_a.weight',
#  'convnet.stage_2.1.bn_a.weight',
#  'convnet.stage_2.1.bn_a.bias',
#  'convnet.stage_2.1.bn_a.running_mean',
#  'convnet.stage_2.1.bn_a.running_var',
#  'convnet.stage_2.1.bn_a.num_batches_tracked',
#  'convnet.stage_2.1.conv_b.weight',
#  'convnet.stage_2.1.bn_b.weight',
#  'convnet.stage_2.1.bn_b.bias',
#  'convnet.stage_2.1.bn_b.running_mean',
#  'convnet.stage_2.1.bn_b.running_var',
#  'convnet.stage_2.1.bn_b.num_batches_tracked',
#  'convnet.stage_2.2.conv_a.weight',
#  'convnet.stage_2.2.bn_a.weight',
#  'convnet.stage_2.2.bn_a.bias',
#  'convnet.stage_2.2.bn_a.running_mean',
#  'convnet.stage_2.2.bn_a.running_var',
#  'convnet.stage_2.2.bn_a.num_batches_tracked',
#  'convnet.stage_2.2.conv_b.weight',
#  'convnet.stage_2.2.bn_b.weight',
#  'convnet.stage_2.2.bn_b.bias',
#  'convnet.stage_2.2.bn_b.running_mean',
#  'convnet.stage_2.2.bn_b.running_var',
#  'convnet.stage_2.2.bn_b.num_batches_tracked',
#  'convnet.stage_2.3.conv_a.weight',
#  'convnet.stage_2.3.bn_a.weight',
#  'convnet.stage_2.3.bn_a.bias',
#  'convnet.stage_2.3.bn_a.running_mean',
#  'convnet.stage_2.3.bn_a.running_var',
#  'convnet.stage_2.3.bn_a.num_batches_tracked',
#  'convnet.stage_2.3.conv_b.weight',
#  'convnet.stage_2.3.bn_b.weight',
#  'convnet.stage_2.3.bn_b.bias',
#  'convnet.stage_2.3.bn_b.running_mean',
#  'convnet.stage_2.3.bn_b.running_var',
#  'convnet.stage_2.3.bn_b.num_batches_tracked',
#  'convnet.stage_2.4.conv_a.weight',
#  'convnet.stage_2.4.bn_a.weight',
#  'convnet.stage_2.4.bn_a.bias',
#  'convnet.stage_2.4.bn_a.running_mean',
#  'convnet.stage_2.4.bn_a.running_var',
#  'convnet.stage_2.4.bn_a.num_batches_tracked',
#  'convnet.stage_2.4.conv_b.weight',
#  'convnet.stage_2.4.bn_b.weight',
#  'convnet.stage_2.4.bn_b.bias',
#  'convnet.stage_2.4.bn_b.running_mean',
#  'convnet.stage_2.4.bn_b.running_var',
#  'convnet.stage_2.4.bn_b.num_batches_tracked',
#  'convnet.stage_3.0.conv_a.weight',
#  'convnet.stage_3.0.bn_a.weight',
#  'convnet.stage_3.0.bn_a.bias',
#  'convnet.stage_3.0.bn_a.running_mean',
#  'convnet.stage_3.0.bn_a.running_var',
#  'convnet.stage_3.0.bn_a.num_batches_tracked',
#  'convnet.stage_3.0.conv_b.weight',
#  'convnet.stage_3.0.bn_b.weight',
#  'convnet.stage_3.0.bn_b.bias',
#  'convnet.stage_3.0.bn_b.running_mean',
#  'convnet.stage_3.0.bn_b.running_var',
#  'convnet.stage_3.0.bn_b.num_batches_tracked',
#  'convnet.stage_3.1.conv_a.weight',
#  'convnet.stage_3.1.bn_a.weight',
#  'convnet.stage_3.1.bn_a.bias',
#  'convnet.stage_3.1.bn_a.running_mean',
#  'convnet.stage_3.1.bn_a.running_var',
#  'convnet.stage_3.1.bn_a.num_batches_tracked',
#  'convnet.stage_3.1.conv_b.weight',
#  'convnet.stage_3.1.bn_b.weight',
#  'convnet.stage_3.1.bn_b.bias',
#  'convnet.stage_3.1.bn_b.running_mean',
#  'convnet.stage_3.1.bn_b.running_var',
#  'convnet.stage_3.1.bn_b.num_batches_tracked',
#  'convnet.stage_3.2.conv_a.weight',
#  'convnet.stage_3.2.bn_a.weight',
#  'convnet.stage_3.2.bn_a.bias',
#  'convnet.stage_3.2.bn_a.running_mean',
#  'convnet.stage_3.2.bn_a.running_var',
#  'convnet.stage_3.2.bn_a.num_batches_tracked',
#  'convnet.stage_3.2.conv_b.weight',
#  'convnet.stage_3.2.bn_b.weight',
#  'convnet.stage_3.2.bn_b.bias',
#  'convnet.stage_3.2.bn_b.running_mean',
#  'convnet.stage_3.2.bn_b.running_var',
#  'convnet.stage_3.2.bn_b.num_batches_tracked',
#  'convnet.stage_3.3.conv_a.weight',
#  'convnet.stage_3.3.bn_a.weight',
#  'convnet.stage_3.3.bn_a.bias',
#  'convnet.stage_3.3.bn_a.running_mean',
#  'convnet.stage_3.3.bn_a.running_var',
#  'convnet.stage_3.3.bn_a.num_batches_tracked',
#  'convnet.stage_3.3.conv_b.weight',
#  'convnet.stage_3.3.bn_b.weight',
#  'convnet.stage_3.3.bn_b.bias',
#  'convnet.stage_3.3.bn_b.running_mean',
#  'convnet.stage_3.3.bn_b.running_var',
#  'convnet.stage_3.3.bn_b.num_batches_tracked',
#  'convnet.stage_3.4.conv_a.weight',
#  'convnet.stage_3.4.bn_a.weight',
#  'convnet.stage_3.4.bn_a.bias',
#  'convnet.stage_3.4.bn_a.running_mean',
#  'convnet.stage_3.4.bn_a.running_var',
#  'convnet.stage_3.4.bn_a.num_batches_tracked',
#  'convnet.stage_3.4.conv_b.weight',
#  'convnet.stage_3.4.bn_b.weight',
#  'convnet.stage_3.4.bn_b.bias',
#  'convnet.stage_3.4.bn_b.running_mean',
#  'convnet.stage_3.4.bn_b.running_var',
#  'convnet.stage_3.4.bn_b.num_batches_tracked',
#  'convnet.fc.weight',
#  'convnet.fc.bias',
#  'fc.weight',
#  'fc.bias']
